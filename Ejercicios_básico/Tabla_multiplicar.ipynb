# %% [markdown]
# # Tabla de multiplicar
# Escribe un programa que pida un número y muestre su tabla de multiplicar del 1 al 10.

# %%
numero = int(input("Intruduce un número para ver su tabla de multiplicar."))

print (f"La tabla de multipicar de {numero} es:")

for e in range(1,11):
    print(f"{numero} x {e} = {numero*e}")
# Out:
# La tabla de multipicar de 2 es:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
