# %% [markdown]
# ### Suma de dos números
# Escribe un programa que pida dos números al usuario y muestre su suma

# %%
num1= int(input("Introduce el primer número para la suma"))
num2= int(input("Introduce el segundo número para la suma"))
resultado = num1 + num2

print(f"La suma de {num1} más {num2} es {resultado}")
# Out:
# La suma de 1 más 2 es 3
